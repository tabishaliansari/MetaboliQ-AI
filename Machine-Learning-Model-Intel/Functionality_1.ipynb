# %% [markdown]
# # MetaboliQ AI
# ### ~ by Mavericks
#
# #### Functionality 1
# This Jupyter Notebook contains the *Random Forest Regressor Model* for the first functionality of MetaboliQ AI.
# Problem Statement: Projecting the number of diabetic patients in a region for the next 10 years.
#
# Developed for:
# 1. Individuals
# 2. Professionals
# 3. Ministry of Health
#
# Output: Projects the number of diabetic patients over the next 10 years.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearnex import patch_sklearn
patch_sklearn()
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
data = pd.read_csv("synthetic_diabetes_data.csv")
data.head()
# Out:
#    Year  Population  Number of Diabetic Patients  \
# 0  1960     5000000                       100000
# 1  1961     5060000                       101200
# 2  1962     5120720                       102414
# 3  1963     5182168                       103643
# 4  1964     5244354                       104887
#
#    Number of Male Diabetic Patients  Number of Female Diabetic Patients  \
# 0                             60000                               40000
# 1                             60720                               40480
# 2                             61448                               40965
# 3                             62186                               41457
# 4                             62932                               41954
#
#    Pollution Level (AQI)  Health Index
# 0                  30.00          0.75
# 1                  31.15          0.73
# 2                  32.30          0.71
# 3                  33.45          0.69
# 4                  34.60          0.67

# %%
data.tail()
# Out:
#     Year  Population  Number of Diabetic Patients  \
# 56  2016     9751663                       195033
# 57  2017     9868683                       197373
# 58  2018     9987107                       199742
# 59  2019    10106952                       202139
# 60  2020    10228236                       204564
#
#     Number of Male Diabetic Patients  Number of Female Diabetic Patients  \
# 56                            117019                               78013
# 57                            118424                               78949
# 58                            119845                               79896
# 59                            121283                               80855
# 60                            122738                               81825
#
#     Pollution Level (AQI)  Health Index
# 56                  94.40         -0.37
# 57                  95.55         -0.39
# 58                  96.70         -0.41
# 59                  97.85         -0.43
# 60                  99.00         -0.45

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.shape
# Out:
# (61, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                61 non-null     int64
#  1   Population                          61 non-null     int64
#  2   Number of Diabetic Patients         61 non-null     int64
#  3   Number of Male Diabetic Patients    61 non-null     int64
#  4   Number of Female Diabetic Patients  61 non-null     int64
#  5   Pollution Level (AQI)               61 non-null     float64
#  6   Health Index                        61 non-null     float64
# dtypes: float64(2), int64(5)
# memory usage: 3.5 KB

# %%
data.describe().T
# Out:
#                                     count          mean           std  \
# Year                                 61.0  1.990000e+03  1.775293e+01
# Population                           61.0  7.310075e+06  1.541263e+06
# Number of Diabetic Patients          61.0  1.462011e+05  3.082520e+04
# Number of Male Diabetic Patients     61.0  8.772046e+04  1.849510e+04
# Number of Female Diabetic Patients   61.0  5.848010e+04  1.233004e+04
# Pollution Level (AQI)                61.0  6.450000e+01  2.041587e+01
# Health Index                         61.0  1.500000e-01  3.550587e-01
#
#                                            min         25%         50%  \
# Year                                   1960.00     1975.00     1990.00
# Population                          5000000.00  5979676.00  7151306.00
# Number of Diabetic Patients          100000.00   119593.00   143026.00
# Number of Male Diabetic Patients      60000.00    71756.00    85815.00
# Number of Female Diabetic Patients    40000.00    47837.00    57210.00
# Pollution Level (AQI)                    30.00       47.25       64.50
# Health Index                             -0.45       -0.15        0.15
#
#                                            75%          max
# Year                                   2005.00      2020.00
# Population                          8552499.00  10228236.00
# Number of Diabetic Patients          171049.00    204564.00
# Number of Male Diabetic Patients     102629.00    122738.00
# Number of Female Diabetic Patients    68419.00     81825.00
# Pollution Level (AQI)                    81.75        99.00
# Health Index                              0.45         0.75

# %%
data.isnull().sum()
# Out:
# Year                                  0
# Population                            0
# Number of Diabetic Patients           0
# Number of Male Diabetic Patients      0
# Number of Female Diabetic Patients    0
# Pollution Level (AQI)                 0
# Health Index                          0
# dtype: int64

# %% [markdown]
# ## Statistical Analysis

# %%
data.mean()
# Out:
# Year                                  1.990000e+03
# Population                            7.310075e+06
# Number of Diabetic Patients           1.462011e+05
# Number of Male Diabetic Patients      8.772046e+04
# Number of Female Diabetic Patients    5.848010e+04
# Pollution Level (AQI)                 6.450000e+01
# Health Index                          1.500000e-01
# dtype: float64

# %%
data.median()
# Out:
# Year                                     1990.00
# Population                            7151306.00
# Number of Diabetic Patients            143026.00
# Number of Male Diabetic Patients        85815.00
# Number of Female Diabetic Patients      57210.00
# Pollution Level (AQI)                      64.50
# Health Index                                0.15
# dtype: float64

# %%
data.var()
# Out:
# Year                                  3.151667e+02
# Population                            2.375491e+12
# Number of Diabetic Patients           9.501932e+08
# Number of Male Diabetic Patients      3.420689e+08
# Number of Female Diabetic Patients    1.520299e+08
# Pollution Level (AQI)                 4.168079e+02
# Health Index                          1.260667e-01
# dtype: float64

# %%
data.std()
# Out:
# Year                                  1.775293e+01
# Population                            1.541263e+06
# Number of Diabetic Patients           3.082520e+04
# Number of Male Diabetic Patients      1.849510e+04
# Number of Female Diabetic Patients    1.233004e+04
# Pollution Level (AQI)                 2.041587e+01
# Health Index                          3.550587e-01
# dtype: float64

# %%
data.cov().T
# Out:
#                                             Year    Population  \
# Year                                3.151667e+02  2.724258e+07
# Population                          2.724258e+07  2.375491e+12
# Number of Diabetic Patients         5.448506e+05  4.750974e+10
# Number of Male Diabetic Patients    3.269101e+05  2.850581e+10
# Number of Female Diabetic Patients  2.179396e+05  1.900383e+10
# Pollution Level (AQI)               3.624417e+02  3.132897e+07
# Health Index                       -6.303333e+00 -5.448516e+05
#
#                                     Number of Diabetic Patients  \
# Year                                               5.448506e+05
# Population                                         4.750974e+10
# Number of Diabetic Patients                        9.501932e+08
# Number of Male Diabetic Patients                   5.701154e+08
# Number of Female Diabetic Patients                 3.800761e+08
# Pollution Level (AQI)                              6.265782e+05
# Health Index                                      -1.089701e+04
#
#                                     Number of Male Diabetic Patients  \
# Year                                                    3.269101e+05
# Population                                              2.850581e+10
# Number of Diabetic Patients                             5.701154e+08
# Number of Male Diabetic Patients                        3.420689e+08
# Number of Female Diabetic Patients                      2.280454e+08
# Pollution Level (AQI)                                   3.759466e+05
# Health Index                                           -6.538201e+03
#
#                                     Number of Female Diabetic Patients  \
# Year                                                      2.179396e+05
# Population                                                1.900383e+10
# Number of Diabetic Patients                               3.800761e+08
# Number of Male Diabetic Patients                          2.280454e+08
# Number of Female Diabetic Patients                        1.520299e+08
# Pollution Level (AQI)                                     2.506305e+05
# Health Index                                             -4.358791e+03
#
#                                     Pollution Level (AQI)   Health Index
# Year                                         3.624417e+02      -6.303333
# Population                                   3.132897e+07 -544851.582667
# Number of Diabetic Patients                  6.265782e+05  -10897.012333
# Number of Male Diabetic Patients             3.759466e+05   -6538.201333
# Number of Female Diabetic Patients           2.506305e+05   -4358.791333
# Pollution Level (AQI)                        4.168079e+02      -7.248833
# Health Index                                -7.248833e+00       0.126067

# %%
data.corr().T
# Out:
#                                         Year  Population  \
# Year                                1.000000    0.995638
# Population                          0.995638    1.000000
# Number of Diabetic Patients         0.995638    1.000000
# Number of Male Diabetic Patients    0.995638    1.000000
# Number of Female Diabetic Patients  0.995638    1.000000
# Pollution Level (AQI)               1.000000    0.995638
# Health Index                       -1.000000   -0.995638
#
#                                     Number of Diabetic Patients  \
# Year                                                   0.995638
# Population                                             1.000000
# Number of Diabetic Patients                            1.000000
# Number of Male Diabetic Patients                       1.000000
# Number of Female Diabetic Patients                     1.000000
# Pollution Level (AQI)                                  0.995638
# Health Index                                          -0.995638
#
#                                     Number of Male Diabetic Patients  \
# Year                                                        0.995638
# Population                                                  1.000000
# Number of Diabetic Patients                                 1.000000
# Number of Male Diabetic Patients                            1.000000
# Number of Female Diabetic Patients                          1.000000
# Pollution Level (AQI)                                       0.995638
# Health Index                                               -0.995638
#
#                                     Number of Female Diabetic Patients  \
# Year                                                          0.995638
# Population                                                    1.000000
# Number of Diabetic Patients                                   1.000000
# Number of Male Diabetic Patients                              1.000000
# Number of Female Diabetic Patients                            1.000000
# Pollution Level (AQI)                                         0.995638
# Health Index                                                 -0.995638
#
#                                     Pollution Level (AQI)  Health Index
# Year                                             1.000000     -1.000000
# Population                                       0.995638     -0.995638
# Number of Diabetic Patients                      0.995638     -0.995638
# Number of Male Diabetic Patients                 0.995638     -0.995638
# Number of Female Diabetic Patients               0.995638     -0.995638
# Pollution Level (AQI)                            1.000000     -1.000000
# Health Index                                    -1.000000      1.000000

# %% [markdown]
# ## Outlier Detection and Removal

# %%
# Boxplot of profit
for col in data.columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(data[col])
    plt.title(col)
    plt.show()
plt.tight_layout()

# %%
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

# Calculate Quartile Deviation
quartile_deviation = (Q3 - Q1) / 2

print("Interquartile Range (IQR):", IQR)
print("Quartile Deviation:", quartile_deviation)
# Out:
# Interquartile Range (IQR): 121073.175
# Quartile Deviation: 60536.5875

# %% [markdown]
# Hence, no outliers are present!

# %% [markdown]
# ## Data Visualization

# %%
for col in data.columns:
    plt.figure(figsize=(6, 4))
    plt.hist(data[col])
    plt.title(col)
    plt.show()
plt.tight_layout()

# %%
for col in data.columns:
    plt.figure(figsize=(6, 4))
    plt.plot(data[col])
    plt.title(col)
    plt.show()
plt.tight_layout()

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %% [markdown]
# # Model Building

# %%
# Creating the features (X) and target (y) variables
X = data['Year'].values.reshape(-1, 1)
y = data['Number of Diabetic Patients'].values

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predict for training data
y_pred = model.predict(X)
y_pred
# Out:
# array([ 94337.98783711,  96066.75764144,  97795.52744578,  99524.29725012,
#        101253.06705445, 102981.83685879, 104710.60666313, 106439.37646746,
#        108168.1462718 , 109896.91607614, 111625.68588048, 113354.45568481,
#        115083.22548915, 116811.99529349, 118540.76509782, 120269.53490216,
#        121998.3047065 , 123727.07451083, 125455.84431517, 127184.61411951,
#        128913.38392384, 130642.15372818, 132370.92353252, 134099.69333686,
#        135828.46314119, 137557.23294553, 139286.00274987, 141014.7725542 ,
#        142743.54235854, 144472.31216288, 146201.08196721, 147929.85177155,
#        149658.62157589, 151387.39138022, 153116.16118456, 154844.9309889 ,
#        156573.70079323, 158302.47059757, 160031.24040191, 161760.01020624,
#        163488.78001058, 165217.54981492, 166946.31961926, 168675.08942359,
#        170403.85922793, 172132.62903227, 173861.3988366 , 175590.16864094,
#        177318.93844528, 179047.70824961, 180776.47805395, 182505.24785829,
#        184234.01766262, 185962.78746696, 187691.5572713 , 189420.32707564,
#        191149.09687997, 192877.86668431, 194606.63648865, 196335.40629298,
#        198064.17609732])

# %%
# Print evaluation metrics
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Absolute Error (MAE): 2451.534665499562
# Mean Squared Error (MSE): 8136311.189318721
# Root Mean Squared Error (RMSE): 2852.4219865438426
# R-squared (R²): 0.9912944901249927

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(data['Year'], data['Number of Diabetic Patients'], color='blue', label='Observed')
plt.plot(data['Year'], y_pred, color='red', label='Fitted Line')
plt.plot(future_years, future_predictions, color='green', linestyle='--', label='Forecast')
plt.xlabel('Year')
plt.ylabel('Number of Diabetic Patients')
plt.title('Linear Regression Forecast of Diabetic Patients')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Predict future values
future_years = np.array([1966, 1967, 1968, 1969, 1970]).reshape(-1, 1)
future_predictions = model.predict(future_years)
# Combine historical and future predictions
future_data = pd.DataFrame({'Year': future_years.flatten(), 'Predicted Patients': future_predictions})
combined_data = pd.concat([data, future_data.set_index('Year')])
future_predictions
# Out:
# array([104710.60666313, 106439.37646746, 108168.1462718 , 109896.91607614,
#        111625.68588048])

# %%
# Predict future values
future_years = np.array([2031, 2032, 2033, 2034, 2035]).reshape(-1, 1)
future_predictions = model.predict(future_years)
# Combine historical and future predictions
future_data = pd.DataFrame({'Year': future_years.flatten(), 'Predicted Patients': future_predictions})
combined_data = pd.concat([data, future_data.set_index('Year')])
future_predictions
# Out:
# array([217080.64394502, 218809.41374936, 220538.1835537 , 222266.95335804,
#        223995.72316237])

# %%
# Predict future values
future_years = np.array([2041, 2042, 2043, 2044, 2045]).reshape(-1, 1)
future_predictions = model.predict(future_years)
# Combine historical and future predictions
future_data = pd.DataFrame({'Year': future_years.flatten(), 'Predicted Patients': future_predictions})
combined_data = pd.concat([data, future_data.set_index('Year')])
future_predictions
# Out:
# array([234368.34198839, 236097.11179273, 237825.88159707, 239554.6514014 ,
#        241283.42120574])

# %%
while True:
    try:
        year = int(input("Please enter the year to predict: "))
        # Predict future value
        future_years = np.array([year]).reshape(-1, 1)
        future_predictions = model.predict(future_years)

        # Combine historical and future predictions
        future_data = pd.DataFrame({'Year': future_years.flatten(), 'Predicted Patients': future_predictions})
        combined_data = pd.concat([data, future_data.set_index('Year')])
        # Print prediction
        print(f"Predicted number of diabetic patients in {year}: {future_predictions[0]:.0f}")
        choice = input("Would you like to predict again? (Y/N): ")
        if choice.lower() == "y":
            continue
        else:
            break
    except ValueError:
        print("Please enter a valid integer year.")
# Out:
# Please enter the year to predict:  2077
# Predicted number of diabetic patients in 2077: 296604
# Would you like to predict again? (Y/N):  y
# Please enter the year to predict:  2020
# Predicted number of diabetic patients in 2020: 198064
# Would you like to predict again? (Y/N):  n

# %% [markdown]
# ### Serializing this trained Linear Regression Model

# %%
from joblib import dump
dump(model, 'Functionality_1.joblib')
# Out:
# ['Functionality_1.joblib']

# %%
# Terminated
